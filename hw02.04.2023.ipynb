# %% [markdown]
# Исправьте фразу, используя новые методы: ['Я', ' ', 'л', 'у', 'б', 'и', 'л', 'ю', ' ', 'у', 'ч', 'е', 'т', 'с', 'я', ' ', 'ы', ' ', 'д', 'и', 'л', 'а', 'т', ' ', 'д', 'а', 'м', 'а', 'ш', 'н', 'е', ' ', 'з', 'о', 'д', 'а', 'н', 'е', 'е'].

# %%
p = ['Я', ' ', 'л', 'у', 'б', 'и', 'л', 'ю', ' ', 'у', 'ч', 'е', 'т', 'с', 'я', ' ', 'ы', ' ', 'д', 'и', 'л', 'а', 'т', ' ', 'д', 'а', 'м', 'а', 'ш', 'н', 'е', ' ', 'з', 'о', 'д', 'а', 'н', 'е', 'е'].

# %% [markdown]
# Исправление оценки за самостоятельную работу (кого не было, тоже сдать): Дано целое число N и список из N целых чисел. Найти сумму всех четных двузначных чисел и произведение всех остальных.
